# %%
from wordcloud import WordCloud

# %%
import feedparser
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud
from wordcloud import WordCloud, STOPWORDS

# %%
from PIL import Image
import numpy as np
from wordcloud import ImageColorGenerator

# %%
import re

# %%
text = open('dump2.txt',encoding='utf-8').read()
t = re.sub('[!@#$]',' ', text)
#stopwords = {'title title'}
# t = t.translate({ord(i): None for i in 'title title'})
wordcloud = WordCloud().generate(t)

# %%
insta = np.array(Image.open('insta.png'))
image_colors = ImageColorGenerator(insta)

# %%
image_colors = ImageColorGenerator(insta)

wc = WordCloud(background_color="black", 
               max_words=2000, 
               mask=mask,
               max_font_size=300, 
               random_state=42)
               
# generate word cloud
wc.generate_from_text(text)
wc.recolor(color_func=image_colors), random_state=3)
wc.to_file("Yun_Dongju.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-31d569310fdc> in <module>
#       9 # generate word cloud
#      10 wc.generate_from_text(text)
# ---> 11 wc.recolor(color_func=color_func, random_state=3)
#      12 wc.to_file("Yun_Dongju.png")
#
# NameError: name 'color_func' is not defined

# %%
image_colors = ImageColorGenerator(insta)
plt.figure(figsize=(12,12))
plt.axis('off')

plt.imshow(wc.recolor(color_func=image_colors), 
           interpolation='bilinear')
plt.show()
