# %%
import requests
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
def crawl(url):
    data = requests.get(url)
    print(data, url)
    return data.content

# %%
url = 'https://www.instagram.com/explore/tags/doll/'

# %%
pageString=crawl(url)
# Out:
# <Response [200]> https://www.instagram.com/explore/tags/doll/

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
import time

# %%
time.sleep(5)
driver.get(url)

# %%
log = driver.find_element_by_xpath("//div[@class='v1Nh3 kIKUG  _bz0w']").click()
time.sleep(5)
log

# %% [markdown]
# 이사이에 태그를 가져오는 함수가 필요하디

# %% [markdown]
# 태그는 span이라는 함수 아래있고  관련된 html코드를 가지고 오자면

# %%
pageString = crawl(url)
# Out:
# <Response [200]> https://www.instagram.com/explore/tags/doll/

# %%
from bs4 import BeautifulSoup

# %%
bsOj = BeautifulSoup(pageString, 'html.parser')
print(bsOj)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js not-logged-in client-root" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# #doll hashtag on Instagram • Photos and Videos
# </title>
# <meta content="noimageindex, noarchive" name="robots"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover" id="viewport" name="viewport"/>
# <link href="/data/manifest.json" rel="manifest"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/metro/ConsumerLibCommons.css/ecdeb303e8df.css" rel="preload" type="text/css">
# <link as="style" crossorigin="anonymous" href="/static/bundles/metro/ConsumerUICommons.css/544ec82e2692.css" rel="preload" type="text/css"/>
# ...

# %%
bsOj.find('title')
# Out:
# <title>
# #doll hashtag on Instagram • Photos and Videos
# </title>

# %%
f = open('dump.txt', 'w', -1,'utf-8')
print(dump, file=f)
f.close()

# %% [markdown]
# 하나의 사진안에 있는 해쉬태그 가져오기는 성공
# 다음장을 가지고 오도록
